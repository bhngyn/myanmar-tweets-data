# %%
#import libraries
from datetime import date, timedelta
import twint
import pandas as pd
import nest_asyncio

#you need this for twint to work in Jupyter
nest_asyncio.apply()

# %%
#configure the Twint search
c = twint.Config()

#configure individual componnents of the search for keywords within #MarXXCoup hashtags with a minimum of 10 likes and has media
c.Search = "body OR bodies OR corpse AND #Apr10Coup OR #Apr11Coup OR #Ar12Coup OR #WhatsHappeningInMyanmar OR #Myanmar AND since:2021-04-10"
c.Media = True
c.Min_likes = 10
c.Pandas = True

#run the search
twint.run.Search(c)
# Out:
# 1381663916887928834 2021-04-12 10:42:02 -0700 <1311revolution> In Bago, where 83 people were massacred within a day, if families want to retrieve dead bodies, they have to pay 120,000 kyats (around 100 USD) per body to terrorists. Moreover they were threatened not to confide to the medias @RFABurmese  #WhatsHappeningInMyanmar #Apr12Coup  https://t.co/WYe9sddxGw
# 1381639415714480131 2021-04-12 09:04:40 -0700 <KhaingEiKhaing> Another unknown dead body in North Dagon bridge today around 5:50PM. Ownerless dead bodies around the country within these days. JUNTA MASSACRE #Apr12Coup #WhatsHappeningInMyanmar  https://t.co/WGZaUlMAY6
# 1381636573993660418 2021-04-12 08:53:23 -0700 <TheKiaThuta> Ko Htet Satt, a hero who has fallen in #BagoMassacre of Inhumane Junta on Apr 10. His Family couldn’t even retrieve his body.  Rest in Power,hero.  #WhatsHappeningInMyanmar #Apr12Coup  https://t.co/5Nwla9eB3H
# ...

# %%
#put the collected data into a pandas dataframe called "tweets_df"
tweets_df = twint.storage.panda.Tweets_df

#show what's inside the dataframe
tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 0 to 142
# Data columns (total 38 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               143 non-null    object
#  1   conversation_id  143 non-null    object
#  2   created_at       143 non-null    float64
#  3   date             143 non-null    object
#  4   timezone         143 non-null    object
#  5   place            143 non-null    object
#  6   tweet            143 non-null    object
#  7   language         143 non-null    object
#  8   hashtags         143 non-null    object
#  9   cashtags         143 non-null    object
#  10  user_id          143 non-null    int64
#  11  user_id_str      143 non-null    object
#  12  username         143 non-null    object
#  13  name             143 non-null    object
#  14  day              143 non-null    int64
#  15  hour             143 non-null    object
# ...

# %%
tweets_df
# Out:
#                       id      conversation_id    created_at  \
# 0    1378768357919399936  1378763734903095300  1.617559e+12
# 1    1378758353053081602  1378758353053081602  1.617557e+12
# 2    1378758207607238657  1378758207607238657  1.617557e+12
# 3    1378748427039727619  1378748427039727619  1.617554e+12
# 4    1378735039702310915  1378735039702310915  1.617551e+12
# ..                   ...                  ...           ...
# 99   1378198427134230529  1378198427134230529  1.617423e+12
# 100  1378197588915142658  1378197588915142658  1.617423e+12
# 101  1378194514125287425  1378194514125287425  1.617422e+12
# 102  1378185598842720264  1378184326836154372  1.617420e+12
# 103  1378177812935319552  1378177812935319552  1.617418e+12
#
#                     date timezone place  \
# 0    2021-04-04 10:56:07    -0700
# 1    2021-04-04 10:16:22    -0700
# 2    2021-04-04 10:15:47    -0700
# 3    2021-04-04 09:36:55    -0700
# 4    2021-04-04 08:43:43    -0700
# ...

# %%
#save the tweets_df dataframe to a csv file using the file name specified in red. it will save to where our project is located
tweets_df.to_csv('BS_0412-update_min-faves-10.csv')
